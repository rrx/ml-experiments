# %% [markdown]
# # Convolutional Autoencoder
#
# https://blog.keras.io/building-autoencoders-in-keras.html

# %%
# %matplotlib inline
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Dropout, Reshape, Flatten
from keras.models import Model, Sequential
import numpy as np
from keras.datasets import mnist
import utils;reload(utils)
utils.disable_scrolling()

# 32 dimensions encoded
encoding_dim = 32
input_shape = (1, 28, 28)
input_vector = Input(shape=input_shape)
encoded_vector = Input(shape=(encoding_dim,))

model_encoder = Sequential(name='encoder')
model_encoder.add(Reshape((1,28,28), input_shape=(784,)))
model_encoder.add(Conv2D(32, 3, 3, activation='relu', border_mode='same'))
model_encoder.add(MaxPooling2D(pool_size=(2, 2), border_mode='same'))
model_encoder.add(Conv2D(32, 3, 3, activation='relu', border_mode='same'))
model_encoder.add(MaxPooling2D(pool_size=(2, 2), border_mode='same'))
model_encoder.summary()

encoder_output_shape = model_encoder.output_shape[1:]
print("Encoded Shape %s, Size: %s" % (encoder_output_shape, np.prod(encoder_output_shape)))

model_decoder = Sequential(name='decoder')
model_decoder.add(Conv2D(32, 3, 3, input_shape=encoder_output_shape, activation='relu', border_mode='same'))
model_decoder.add(UpSampling2D(size=(2, 2)))
model_decoder.add(Conv2D(32, 3, 3, activation='relu', border_mode='same'))
model_decoder.add(UpSampling2D(size=(2, 2)))
model_decoder.add(Conv2D(1, 3, 3, activation='relu', border_mode='same'))
model_decoder.add(Flatten())
model_decoder.summary()

model = Sequential(name='autoencoder')
model.add(model_encoder)
model.add(model_decoder)
model.summary()

data = utils.MNIST()
batches = []
batches = data.get_autoencode_training_batches(batch_size=100)
val_batches = data.get_autoencode_test_batches(batch_size=100)
# Out:
# Using Theano backend.
# autoscrolling long output is disabled
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# reshape_1 (Reshape)              (None, 1, 28, 28)     0           reshape_input_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 32, 28, 28)    320         reshape_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 32, 14, 14)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 32, 14, 14)    9248        maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)    (None, 32, 7, 7)      0           convolution2d_2[0][0]
# ====================================================================================================
# Total params: 9568
# ____________________________________________________________________________________________________
# Encoded Shape (32, 7, 7), Size: 1568
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_3 (Convolution2D)  (None, 32, 7, 7)      9248        convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)    (None, 32, 14, 14)    0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 32, 14, 14)    9248        upsampling2d_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)    (None, 32, 28, 28)    0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 1, 28, 28)     289         upsampling2d_2[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 784)           0           convolution2d_5[0][0]
# ====================================================================================================
# Total params: 18785
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# encoder (Sequential)             (None, 32, 7, 7)      9568
# ____________________________________________________________________________________________________
# decoder (Sequential)             (None, 784)           18785       maxpooling2d_2[0][0]
# ====================================================================================================
# Total params: 28353
# ____________________________________________________________________________________________________

# %%
# Fit data with regular training, as well as noisy training sets
N = batches.N
#N = 100
epochs = 2
from keras.callbacks import History 
history = History()
model.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=['accuracy'])
callback = utils.VisualCallback(model_encoder, model_decoder, history, val_batches, 100)
model.fit_generator(batches, N, epochs, verbose=0, callbacks=[history, callback])
# Out:
# Training Set Size 120000
# Mean Encoded: 0.04958580
# Epoch 1/2, Loss: 0.20212 Acc: 0.80919 Val Loss: 0.12666 Val Acc: 0.80071
# Mean Encoded: 0.09531672
# Epoch 2/2, Loss: 0.12221 Acc: 0.81143 Val Loss: 0.11518 Val Acc: 0.81735
# Mean Encoded: 0.09689526

# %%
reload(utils)
utils.save_model(model, "models/convolutional_autoencoder_32.autoencoder")
utils.save_model(model_encoder, "models/convolutional_autoencoder_32.encoder")
utils.save_model(model_decoder, "models/convolutional_autoencoder_32.decoder")
# Out:
# Model saved: models/convolutional_autoencoder_32.autoencoder.model.json
# Weights saved: models/convolutional_autoencoder_32.autoencoder.weights.h5
# Model saved: models/convolutional_autoencoder_32.encoder.model.json
# Weights saved: models/convolutional_autoencoder_32.encoder.weights.h5
# Model saved: models/convolutional_autoencoder_32.decoder.model.json
# Weights saved: models/convolutional_autoencoder_32.decoder.weights.h5
